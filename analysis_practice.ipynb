# %%
from database_library import DatabaseLibrary
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plot_library as pl

# %%
database = DatabaseLibrary()

# %%
aapl_df = database.get_rows('daily', ['AAPL'])
print(aapl_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              1258 non-null   datetime64[ns]
#  1   open              1258 non-null   float64
#  2   high              1258 non-null   float64
#  3   low               1258 non-null   float64
#  4   close             1258 non-null   float64
#  5   adjClose          1258 non-null   float64
#  6   volume            1258 non-null   float64
#  7   unadjustedVolume  1258 non-null   float64
#  8   change            1258 non-null   float64
#  9   changePercent     1258 non-null   float64
#  10  vwap              1258 non-null   float64
#  11  ticker            1258 non-null   object
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 118.1+ KB
# None

# %%
pl.plot_candlesticks(aapl_df)
